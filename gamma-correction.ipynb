# %% [markdown]
# <a href="https://colab.research.google.com/github/GlinskiiIvan/MRI-colab/blob/main/gamma-correction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import math
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
# Загрузка изображения
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Чтение изображения в градациях серого
img = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)

# Проверка
if img is None:
    raise ValueError("Не удалось загрузить изображение!")

# Отображение
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title("Оригинал")
plt.imshow(img, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.hist(img.ravel(), bins=256, range=(0, 256))
plt.title("Гистограмма оригинала")
# Out:
#      <input type="file" id="files-752beb32-dcb5-44d0-a9cd-8438537de9dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-752beb32-dcb5-44d0-a9cd-8438537de9dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
range_values = [1, 0.8, 0.6, 0.4, 0.2]
c = 1

# Создаём сетку 1x5
fig, axes = plt.subplots(1, 5, figsize=(16, 4))
fig.suptitle("Гамма коррекция", fontsize=16)

for idx, g in enumerate(range_values):
    gamma_img = c * img.astype(np.float32) ** g

    gamma_img = np.clip(gamma_img, 0, 255).astype(np.uint8)

    # Определяем позицию в сетке
    ax = axes[idx]
    ax.imshow(gamma_img, cmap='gray')
    ax.set_title(f"g={g}")
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Загрузка изображения
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Чтение изображения в градациях серого
img = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)

# Проверка
if img is None:
    raise ValueError("Не удалось загрузить изображение!")

range_values = [1, 0.8, 0.6, 0.4, 0.2]
c = 1

# Создаём сетку 1x5
fig, axes = plt.subplots(1, 5, figsize=(16, 4))
fig.suptitle("Гамма коррекция", fontsize=16)

for idx, g in enumerate(range_values):
    gamma_img = c * img ** g

    # Определяем позицию в сетке
    ax = axes[idx]
    ax.imshow(gamma_img, cmap='gray')
    ax.set_title(f"g={g}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-3733f707-b789-4509-8d59-a31de0e6e982" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3733f707-b789-4509-8d59-a31de0e6e982">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Загрузка изображения
uploaded = files.upload()
filename = list(uploaded.keys())[0]

# Чтение изображения в градациях серого
img = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)

# Проверка
if img is None:
    raise ValueError("Не удалось загрузить изображение!")

range_values = [1, 1.2, 1.4, 1.6, 1.8]
c = 1

# Создаём сетку 1x5
fig, axes = plt.subplots(1, 5, figsize=(16, 4))
fig.suptitle("Гамма коррекция", fontsize=16)

for idx, g in enumerate(range_values):
    gamma_img = c * img ** g

    # Определяем позицию в сетке
    ax = axes[idx]
    ax.imshow(gamma_img, cmap='gray')
    ax.set_title(f"g={g}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-7a4092c1-d8bd-46b2-9ab9-0f76990cad00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a4092c1-d8bd-46b2-9ab9-0f76990cad00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
